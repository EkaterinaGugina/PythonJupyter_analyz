# %% [markdown]
# <a href="https://colab.research.google.com/github/EkaterinaGugina/PythonJupyter_analyzTaxiTabl/blob/main/Seminar11_11_22_Taxi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('2_taxi_nyc.csv')
df
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp 01  pcp 06  pcp 24   sd
# ...

# %%
df.dtypes
# Out:
# pickup_dt        object
# pickup_month     object
# borough          object
# pickups           int64
# hday             object
# spd             float64
# vsb             float64
# temp            float64
# dewp            float64
# slp             float64
# pcp 01          float64
# pcp 06          float64
# pcp 24          float64
# sd              float64
# dtype: object

# %%
df.hday
# Out:
# 0        Y
# 1        Y
# 2        Y
# 3        Y
# 4        Y
#         ..
# 29096    N
# 29097    N
# 29098    N
# 29099    N
# 29100    N
# Name: hday, Length: 29101, dtype: object

# %%
df = df.rename(columns={'pcp 01': 'pcp_01', 'pcp 06': 'pcp_06','pcp 24': 'pcp_24'})

# %%
df
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp_01  pcp_06  pcp_24   sd
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29101 entries, 0 to 29100
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   pickup_dt     29101 non-null  object
#  1   pickup_month  29101 non-null  object
#  2   borough       26058 non-null  object
#  3   pickups       29101 non-null  int64
#  4   hday          29101 non-null  object
#  5   spd           29101 non-null  float64
#  6   vsb           29101 non-null  float64
#  7   temp          29101 non-null  float64
#  8   dewp          29101 non-null  float64
#  9   slp           29101 non-null  float64
#  10  pcp_01        29101 non-null  float64
#  11  pcp_06        29101 non-null  float64
#  12  pcp_24        29101 non-null  float64
#  13  sd            29101 non-null  float64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 3.1+ MB

# %%
df.shape
# Out:
# (29101, 14)

# %%
df.query("borough == 'Manhattan'").shape[0]
# Out:
# 4343

# %%
df.borough.value_counts()
# Out:
# Bronx            4343
# Brooklyn         4343
# EWR              4343
# Manhattan        4343
# Queens           4343
# Staten Island    4343
# Name: borough, dtype: int64

# %%
df.groupby('borough').agg({'pickups':'sum'})
# Out:
#                 pickups
# borough
# Bronx            220047
# Brooklyn        2321035
# EWR                 105
# Manhattan      10367841
# Queens          1343528
# Staten Island      6957

# %%
df.groupby('borough').agg({'pickups':'sum'}).sort_values('pickups')
# Out:
#                 pickups
# borough
# EWR                 105
# Staten Island      6957
# Bronx            220047
# Queens          1343528
# Brooklyn        2321035
# Manhattan      10367841

# %%
df.groupby('borough').agg({'pickups':'sum'}).sort_values('pickups', ascending = False)
# Out:
#                 pickups
# borough
# Manhattan      10367841
# Brooklyn        2321035
# Queens          1343528
# Bronx            220047
# Staten Island      6957
# EWR                 105

# %%
df.groupby('borough').agg({'pickups':'sum'}).idxmin()
# Out:
# pickups    EWR
# dtype: object

# %%
df.groupby('borough').agg({'pickups':'sum'}).idxmax()
# Out:
# pickups    Manhattan
# dtype: object

# %%
df.groupby(['borough', 'hday']).agg({'pickups':'mean'}).round(2)
# Out:
#                     pickups
# borough       hday
# Bronx         N       50.77
#               Y       48.07
# Brooklyn      N      534.73
#               Y      527.01
# EWR           N        0.02
#               Y        0.04
# Manhattan     N     2401.30
#               Y     2035.93
# Queens        N      308.90
#               Y      320.73
# Staten Island N        1.61
#               Y        1.50

# %%
df.groupby(['borough', 'pickup_month']).agg({'pickups':'sum'})
# Out:
#                             pickups
# borough       pickup_month
# Bronx         Apr             34617
#               Feb             28694
#               Jan             22461
#               Jun             49006
#               Mar             32232
#               May             53037
# Brooklyn      Apr            378095
#               Feb            328650
#               Jan            309011
#               Jun            482466
#               Mar            346726
#               May            476087
# EWR           Apr                10
#               Feb                14
#               Jan                11
#               Jun                29
#               Mar                14
#               May                27
# Manhattan     Apr           1648278
#               Feb           1718571
#               Jan           1455543
#               Jun           1995388
#               Mar           1661261
#               May           1888800
# ...

# %%
df.groupby(['borough', 'pickup_month']).agg({'pickups':'sum'}).sort_values('pickups', ascending = False)
# Out:
#                             pickups
# borough       pickup_month
# Manhattan     Jun           1995388
#               May           1888800
#               Feb           1718571
#               Mar           1661261
#               Apr           1648278
#               Jan           1455543
# Brooklyn      Jun            482466
#               May            476087
#               Apr            378095
#               Mar            346726
#               Feb            328650
#               Jan            309011
# Queens        Jun            286311
#               May            275893
#               Mar            219561
#               Apr            216857
#               Feb            185695
#               Jan            159211
# Bronx         May             53037
#               Jun             49006
#               Apr             34617
#               Mar             32232
#               Feb             28694
#               Jan             22461
# ...

# %%
df.groupby(['borough', 'pickup_month'], as_index = False).agg({'pickups':'sum'}).sort_values('pickups', ascending = False)
# Out:
#           borough pickup_month  pickups
# 21      Manhattan          Jun  1995388
# 23      Manhattan          May  1888800
# 19      Manhattan          Feb  1718571
# 22      Manhattan          Mar  1661261
# 18      Manhattan          Apr  1648278
# 20      Manhattan          Jan  1455543
# 9        Brooklyn          Jun   482466
# 11       Brooklyn          May   476087
# 6        Brooklyn          Apr   378095
# 10       Brooklyn          Mar   346726
# 7        Brooklyn          Feb   328650
# 8        Brooklyn          Jan   309011
# 27         Queens          Jun   286311
# 29         Queens          May   275893
# 28         Queens          Mar   219561
# 24         Queens          Apr   216857
# 25         Queens          Feb   185695
# 26         Queens          Jan   159211
# 5           Bronx          May    53037
# 3           Bronx          Jun    49006
# 0           Bronx          Apr    34617
# 4           Bronx          Mar    32232
# ...

# %%
df.groupby(["borough","hday"]).agg({'pickups':'mean'}).query("hday == 'Y'").round(2)
# Out:
#                     pickups
# borough       hday
# Bronx         Y       48.07
# Brooklyn      Y      527.01
# EWR           Y        0.04
# Manhattan     Y     2035.93
# Queens        Y      320.73
# Staten Island Y        1.50

# %%
df.groupby(["borough","pickup_month"], as_index=False).agg({'pickups':'sum'}).sort_values('pickups',ascending=False).query("pickup_month == 'Feb'")
# Out:
#           borough pickup_month  pickups
# 19      Manhattan          Feb  1718571
# 7        Brooklyn          Feb   328650
# 25         Queens          Feb   185695
# 1           Bronx          Feb    28694
# 31  Staten Island          Feb      903
# 13            EWR          Feb       14

# %%
df
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp_01  pcp_06  pcp_24   sd
# ...

# %%
def f_to_c(col):
  c = round((col-32) * 5.0 / 9.0, 2)
  return c

# %%
df['temp_C'] = f_to_c(df['temp'])

# %%
df
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp_01  pcp_06  pcp_24   sd  temp_C
# ...

# %%
df = df.rename(columns={'temp': 'temp_f'})

# %%
df
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp_f  dewp     slp  pcp_01  pcp_06  pcp_24   sd  temp_C
# ...
